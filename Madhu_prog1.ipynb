# %% [markdown]
# **Python** beginner's tutorial

# %%
# storing a number
a = 144
print(a)
# Out:
# 144

# %%
# storing a number
b = 144
print(b)
# Out:
# 144

# %%
c=a+b
print(c)
# Out:
# 288

# %%
# storing a number
a = 100
print(a)
# Out:
# 100

# %%
# storing a number
b = 144
print(b)
# Out:
# 144

# %%
c=a+b
print(c)
# Out:
# 244

# %%
# text
d = "this is a sentence"
print(d)
# Out:
# this is a sentence

# %%
d
# Out:
# 'this is a sentence'

# %% [markdown]
# what can we do with these variables ?

# %%
a = 3
b = 34
d = a+b
print(d)
# Out:
# 37

# %%
c
# Out:
# 244

# %%
print(d+c)
# Out:
# 281

# %%
# how to change and copy variables

# %%
a=18
print(a)
# Out:
# 18

# %%
e=a
print(e)
# Out:
# 18

# %%
# types of variables
# integer variable
a=9
print(a)
print(type(a))
# Out:
# 9
# <class 'int'>

# %%
# types of variables
# float variable
a=1.00
print(a)
print(type(a))
# Out:
# 1.0
# <class 'float'>

# %%
# types of variables
# boolean variable (true or false)
a=True
print(a)
print(type(a))
# Out:
# True
# <class 'bool'>

# %%
# types of variables
# string variable
a="5"
print(a)
print(type(a))
# Out:
# 5
# <class 'str'>

# %%
# types of variables
# concatenate string
d="09-"
m="11-"
y="2020"
a=d+m+y
print(a)
print(type(a))
# Out:
# 09-11-2020
# <class 'str'>

# %%
# types of variables
# Array or list variable
a=[1,2,3]
print(a)
print(type(a))
# Out:
# [1, 2, 3]
# <class 'list'>

# %%
# types of variables
# Array or list variable
a=[1,2,3,"text","variables"]
print(a)
print(type(a))
# Out:
# [1, 2, 3, 'text', 'variables']
# <class 'list'>

# %%
# types of variables
# Array or list variable
a=[1,2,3]
print(a[2])
print(type(a))
# Out:
# 3
# <class 'list'>

# %%
# types of variables
# indexing lists 
a=[1,2,3]
print(a[0])
print(a[1])
print(a[2])
# Out:
# 1
# 2
# 3

# %%
a.append(4)
print(a)
# Out:
# [1, 2, 3, 4]

# %%
a[3]=5
print(a)
# Out:
# [1, 2, 3, 5]

# %%
print("all elements of variable a",a[:])
# Out:
# all elements of variable a [1, 2, 3, 5]

# %%
print("all elements of variable a from 2nd positions onwards",a[1:])
# Out:
# all elements of variable a from 2nd positions onwards [2, 3, 5]

# %%
print("all elements of variable a from 2nd to 4th position",a[1:3])
# Out:
# all elements of variable a from 2nd to 4th position [2, 3]

# %%
print("all elements of variable a from 3r position backwards",a[:-1])
# Out:
# all elements of variable a from 3r position backwards [1, 2, 3]

# %%
a="joe mama so fat"
a
# Out:
# 'joe mama so fat'

# %%
a=10
b=20
a=a*b
b=a/b
a=a/b
print("value of a",a)
print("value of b",b)
# Out:
# value of a 20.0
# value of b 10.0
