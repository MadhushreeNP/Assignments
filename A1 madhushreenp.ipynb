# %% [markdown]
# ### Variables and data types

# %% [markdown]
# Variable Assignment

# %%
x=5

# %%
x
# Out:
# 5

# %% [markdown]
# Calculations With Variables(sum,sub,multi,exponential,remainder,division)

# %%
x+2
# Out:
# 7

# %%
x-2
# Out:
# 3

# %%
x*2
# Out:
# 10

# %%
x**2
# Out:
# 25

# %%
x%2
# Out:
# 1

# %%
x/2
# Out:
# 2.5

# %% [markdown]
# ## Types and Type Conversion

# %%
int(1) , int(2.2)
# Out:
# (1, 2)

# %%
str('1'),str('True')
# Out:
# ('1', 'True')

# %%
float(1.0),float(2)
# Out:
# (1.0, 2.0)

# %%
bool(),bool(1),bool(25)
# Out:
# (False, True, True)

# %% [markdown]
# ## Strings

# %%
my_string ='My name is Madhushreenp '

# %%
my_string
# Out:
# 'My name is Madhushreenp '

# %% [markdown]
# String operation

# %%
my_string * 2
# Out:
# 'My name is Madhushreenp My name is Madhushreenp '

# %%
my_string + 'from AE'
# Out:
# 'My name is Madhushreenp from AE'

# %%
'm' in my_string
# Out:
# True

# %%
'j' in my_string
# Out:
# False
