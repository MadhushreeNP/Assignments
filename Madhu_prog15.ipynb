# %%
import numpy

speed = [99,98,87,88,111,86,103,87,94,78,77,86,85]

x = numpy.mean(speed)

print(x)
# Out:
# 90.6923076923077

# %%
import numpy

speed = [99,98,87,88,111,86,103,87,94,78,77,86,85]

x = numpy.median(speed)

print(x)
# Out:
# 87.0

# %%
from scipy import stats

speed = [99,98,87,88,111,86,103,87,94,78,77,86,85]

x = stats.mode(speed)

print(x)
# Out:
# ModeResult(mode=array([86]), count=array([2]))

# %%
import numpy

speed = [99,98,87,88,111,86,103,87,94,78,77,86,85]

x = numpy.var(speed)

print(x)
# Out:
# 88.98224852071006

# %%
import numpy

speed = [99,98,87,88,111,86,103,87,94,78,77,86,85]

x = numpy.mean(speed)
y = numpy.std(speed)
z = numpy.var(speed)

print(x)
print(y)
print(z)
# Out:
# 90.6923076923077
# 9.433040258618112
# 88.98224852071006

# %%
import numpy

speed = [99,98,87,88,111,86,103,87,94,78,77,86,85]

x = numpy.mean(speed)
y = numpy.std(speed)
z = numpy.var(speed)

print(x,y,z)
# Out:
# 90.6923076923077 9.433040258618112 88.98224852071006

# %%
import numpy

age = [99,98,87,88,111,86,103,87,94,78,77,86,85,22,54,93.352,39,62,69]

x = numpy.percentile(age,78)

print(x)
# Out:
# 94.16

# %%
import numpy

age = [99,98,87,88,111,86,103,87,94,78,77,86,85,22,54,93.352,39,62,69]

x = numpy.percentile(age,75)

print(x)
# Out:
# 93.676

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0,1.0,100000)

plt.hist(x,100)
plt.show()

# %%
#scatter plot
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,93,97,77,78,85]

plt.scatter(x,y)
